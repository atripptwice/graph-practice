# %%
#Following Youtube https://www.youtube.com/watch?v=3Xc3CA655Y4
#Adding my own ideas also 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Basic Graph

# %%
#Make x and y 
x = [i for i in range(0,100)]
y = [i for i in range(0,200,2)]
x_tick_list = [i for i in range(0,110,10)]
y_tick_list = [i for i in range(0,200,20)]
#formatting 
title_font = {'fontsize':20,'fontname':'Arial','color':'Purple'}
axis_font = {'fontsize':13,'fontname':'Arial','color':'Purple'}
plt.plot(x,y,label="Thing being plotted",color="Purple",linewidth=2)
plt.xticks(x_tick_list)
plt.yticks(y_tick_list)
plt.tick_params(color="Green",length= 10,width =2)
plt.title("My First Graph (not really..)",fontdict= title_font)
plt.xlabel("X Axis",fontdict = axis_font)
plt.ylabel("Y Axis",fontdict= axis_font)
plt.legend()
# show plot
plt.show()
